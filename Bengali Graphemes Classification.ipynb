# %% [markdown]
# # Classifying the components of handwritten Bengali
#
# This is a kaggle notebook whose data can be found at: https://www.kaggle.com/c/bengaliai-cv19/data
#
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)

# %%
#Loading libraries

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from tqdm.auto import tqdm
from glob import glob
import time, gc
import cv2

from tensorflow import keras
import matplotlib.image as mpimg
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Model
from keras.models import clone_model
from keras.layers import Dense,Conv2D,Flatten,MaxPool2D,Dropout,BatchNormalization, Input
from keras.optimizers import Adam
from keras.callbacks import ReduceLROnPlateau
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import PIL.Image as Image, PIL.ImageDraw as ImageDraw, PIL.ImageFont as ImageFont
from matplotlib import pyplot as plt
import seaborn as sns

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.
# Out:
# Using TensorFlow backend.
# /kaggle/input/kalpurush-fonts/kalpurush-2.ttf
# /kaggle/input/bengaliai-cv19/train.csv
# /kaggle/input/bengaliai-cv19/train_image_data_2.parquet
# /kaggle/input/bengaliai-cv19/test_image_data_1.parquet
# /kaggle/input/bengaliai-cv19/class_map.csv
# /kaggle/input/bengaliai-cv19/train_multi_diacritics.csv
# /kaggle/input/bengaliai-cv19/train_image_data_3.parquet
# /kaggle/input/bengaliai-cv19/test_image_data_2.parquet
# /kaggle/input/bengaliai-cv19/train_image_data_1.parquet
# /kaggle/input/bengaliai-cv19/test_image_data_0.parquet
# /kaggle/input/bengaliai-cv19/test.csv
# /kaggle/input/bengaliai-cv19/class_map_corrected.csv
# /kaggle/input/bengaliai-cv19/train_image_data_0.parquet
# /kaggle/input/bengaliai-cv19/sample_submission.csv
# /kaggle/input/bengaliai-cv19/test_image_data_3.parquet

# %%
train_df_ = pd.read_csv('/kaggle/input/bengaliai-cv19/train.csv')
test_df_ = pd.read_csv('/kaggle/input/bengaliai-cv19/test.csv')
class_map_df = pd.read_csv('/kaggle/input/bengaliai-cv19/class_map.csv')
sample_sub_df = pd.read_csv('/kaggle/input/bengaliai-cv19/sample_submission.csv')

# %%
train_df_.head()
# Out:
#   image_id  grapheme_root  vowel_diacritic  consonant_diacritic grapheme
# 0  Train_0             15                9                    5   ক্ট্রো
# 1  Train_1            159                0                    0        হ
# 2  Train_2             22                3                    5     খ্রী
# 3  Train_3             53                2                    2     র্টি
# 4  Train_4             71                9                    5     থ্রো

# %%
test_df_.head()
# Out:
#                        row_id image_id            component
# 0  Test_0_consonant_diacritic   Test_0  consonant_diacritic
# 1        Test_0_grapheme_root   Test_0        grapheme_root
# 2      Test_0_vowel_diacritic   Test_0      vowel_diacritic
# 3  Test_1_consonant_diacritic   Test_1  consonant_diacritic
# 4        Test_1_grapheme_root   Test_1        grapheme_root

# %%
sample_sub_df.head()
# Out:
#                        row_id  target
# 0  Test_0_consonant_diacritic       0
# 1        Test_0_grapheme_root       0
# 2      Test_0_vowel_diacritic       0
# 3  Test_1_consonant_diacritic       0
# 4        Test_1_grapheme_root       0

# %%
class_map_df.head()
# Out:
#   component_type  label component
# 0  grapheme_root      0         ং
# 1  grapheme_root      1         ঃ
# 2  grapheme_root      2         অ
# 3  grapheme_root      3         আ
# 4  grapheme_root      4         ই

# %%
print(f'Size of training data: {train_df_.shape}')
print(f'Size of test data: {test_df_.shape}')
print(f'Size of class map: {class_map_df.shape}')
# Out:
# Size of training data: (200840, 5)
# Size of test data: (36, 3)
# Size of class map: (186, 3)

# %% [markdown]
# ## Exploratory Data Analysis
#
# Analyzing data sets to summarize their main characteristics with visual methods.
#
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)

# %%
HEIGHT = 236
WIDTH = 236

def get_n(df, field, n, top=True):
    top_graphemes = df.groupby([field]).size().reset_index(name='counts')['counts'].sort_values(ascending=not top)[:n]
    top_grapheme_roots = top_graphemes.index
    top_grapheme_counts = top_graphemes.values
    top_graphemes = class_map_df[class_map_df['component_type'] == field].reset_index().iloc[top_grapheme_roots]
    top_graphemes.drop(['component_type', 'label'], axis=1, inplace=True)
    top_graphemes.loc[:, 'count'] = top_grapheme_counts
    return top_graphemes

def image_from_char(char):
    image = Image.new('RGB', (WIDTH, HEIGHT))
    draw = ImageDraw.Draw(image)
    myfont = ImageFont.truetype('/kaggle/input/kalpurush-fonts/kalpurush-2.ttf', 120)
    w, h = draw.textsize(char, font=myfont)
    draw.text(((WIDTH - w) / 2,(HEIGHT - h) / 3), char, font=myfont)

    return image

# %% [markdown]
# ### Number of unique values

# %%
print(f'Number of unique grapheme roots: {train_df_["grapheme_root"].nunique()}')
print(f'Number of unique vowel diacritic: {train_df_["vowel_diacritic"].nunique()}')
print(f'Number of unique consonant diacritic: {train_df_["consonant_diacritic"].nunique()}')
# Out:
# Number of unique grapheme roots: 168
# Number of unique vowel diacritic: 11
# Number of unique consonant diacritic: 7

# %% [markdown]
# ### Most used top 10 Grapheme Roots in training set

# %%
top_10_roots = get_n(train_df_, 'grapheme_root', 10)
top_10_roots
# Out:
#      index component  count
# 72      72         দ   5736
# 64      64         ত   5596
# 13      13         ক   5420
# 107    107         ব   5321
# 23      23         গ   5149
# 96      96         প   4926
# 113    113         ভ   4395
# 147    147         স   4392
# 133    133         শ   4374
# 115    115         ম   4015

# %%
f, ax = plt.subplots(2, 5, figsize=(16, 8))
ax = ax.flatten()

for i in range(10):
    ax[i].imshow(image_from_char(top_10_roots['component'].iloc[i]), cmap='Greys')

# %% [markdown]
# ### Least used 10 Grapheme Roots in training set

# %%
bottom_10_roots = get_n(train_df_, 'grapheme_root', 10, False)
bottom_10_roots
# Out:
#      index component  count
# 73      73       দ্ঘ    130
# 33      33     ঙ্ক্ত    136
# 102    102       প্স    141
# 158    158       স্স    143
# 45      45     জ্জ্ব    144
# 130    130       ল্ব    144
# 1        1         ঃ    145
# 12      12         ঔ    146
# 0        0         ং    147
# 63      63       ণ্ণ    149

# %%
f, ax = plt.subplots(2, 5, figsize=(16, 8))
ax = ax.flatten()

for i in range(10):
    ax[i].imshow(image_from_char(bottom_10_roots['component'].iloc[i]), cmap='Greys')

# %% [markdown]
# ### Top 5 Vowel Diacritic in taining data

# %%
top_5_vowels = get_n(train_df_, 'vowel_diacritic', 5)
top_5_vowels
# Out:
#    index component  count
# 0    168         0  41508
# 1    169         া  36886
# 7    175         ে  28723
# 2    170         ি  25967
# 4    172         ু  18848

# %%
f, ax = plt.subplots(1, 5, figsize=(16, 8))
ax = ax.flatten()

for i in range(5):
    ax[i].imshow(image_from_char(top_5_vowels['component'].iloc[i]), cmap='Greys')

# %% [markdown]
# ### Top 5 Consonant Diacritic in training data

# %%
top_5_consonants = get_n(train_df_, 'consonant_diacritic', 5)
top_5_consonants
# Out:
#    index component   count
# 0    179         0  125278
# 2    181        র্   23465
# 5    184        ্র   21397
# 4    183        ্য   21270
# 1    180         ঁ    7424

# %%
f, ax = plt.subplots(1, 5, figsize=(16, 8))
ax = ax.flatten()

for i in range(5):
    ax[i].imshow(image_from_char(top_5_consonants['component'].iloc[i]), cmap='Greys')

# %%
train_df_ = train_df_.drop(['grapheme'], axis=1, inplace=False)

# %%
train_df_[['grapheme_root', 'vowel_diacritic', 'consonant_diacritic']] = train_df_[['grapheme_root', 'vowel_diacritic', 'consonant_diacritic']].astype('uint8')

# %%
IMG_SIZE=64
N_CHANNELS=1

# %% [markdown]
# ## Image Processing
# Applying image processing while resizing the images, which will center crop the region of interest from the original images.
#
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)

# %%
def resize(df, size=64, need_progress_bar=True):
    resized = {}
    resize_size=64
    if need_progress_bar:
        for i in tqdm(range(df.shape[0])):
            image=df.loc[df.index[i]].values.reshape(137,236)
            _, thresh = cv2.threshold(image, 30, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)
            contours, _ = cv2.findContours(thresh,cv2.RETR_LIST,cv2.CHAIN_APPROX_SIMPLE)[-2:]

            idx = 0 
            ls_xmin = []
            ls_ymin = []
            ls_xmax = []
            ls_ymax = []
            for cnt in contours:
                idx += 1
                x,y,w,h = cv2.boundingRect(cnt)
                ls_xmin.append(x)
                ls_ymin.append(y)
                ls_xmax.append(x + w)
                ls_ymax.append(y + h)
            xmin = min(ls_xmin)
            ymin = min(ls_ymin)
            xmax = max(ls_xmax)
            ymax = max(ls_ymax)

            roi = image[ymin:ymax,xmin:xmax]
            resized_roi = cv2.resize(roi, (resize_size, resize_size),interpolation=cv2.INTER_AREA)
            resized[df.index[i]] = resized_roi.reshape(-1)
    else:
        for i in range(df.shape[0]):
            #image = cv2.resize(df.loc[df.index[i]].values.reshape(137,236),(size,size),None,fx=0.5,fy=0.5,interpolation=cv2.INTER_AREA)
            image=df.loc[df.index[i]].values.reshape(137,236)
            _, thresh = cv2.threshold(image, 30, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)
            contours, _ = cv2.findContours(thresh,cv2.RETR_LIST,cv2.CHAIN_APPROX_SIMPLE)[-2:]

            idx = 0 
            ls_xmin = []
            ls_ymin = []
            ls_xmax = []
            ls_ymax = []
            for cnt in contours:
                idx += 1
                x,y,w,h = cv2.boundingRect(cnt)
                ls_xmin.append(x)
                ls_ymin.append(y)
                ls_xmax.append(x + w)
                ls_ymax.append(y + h)
            xmin = min(ls_xmin)
            ymin = min(ls_ymin)
            xmax = max(ls_xmax)
            ymax = max(ls_ymax)

            roi = image[ymin:ymax,xmin:xmax]
            resized_roi = cv2.resize(roi, (resize_size, resize_size),interpolation=cv2.INTER_AREA)
            resized[df.index[i]] = resized_roi.reshape(-1)
    resized = pd.DataFrame(resized).T
    return resized

# %%
def get_dummies(df):
    cols = []
    for col in df:
        cols.append(pd.get_dummies(df[col].astype(str)))
    return pd.concat(cols, axis=1)

# %% [markdown]
# ### Basic Model

# %%
inputs = Input(shape = (IMG_SIZE, IMG_SIZE, 1))

model = Conv2D(filters=32, kernel_size=(3, 3), padding='SAME', activation='relu', input_shape=(IMG_SIZE, IMG_SIZE, 1))(inputs)
model = Conv2D(filters=32, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = Conv2D(filters=32, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = Conv2D(filters=32, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = BatchNormalization(momentum=0.15)(model)
model = MaxPool2D(pool_size=(2, 2))(model)
model = Conv2D(filters=32, kernel_size=(5, 5), padding='SAME', activation='relu')(model)
model = Dropout(rate=0.3)(model)

model = Conv2D(filters=64, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = Conv2D(filters=64, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = Conv2D(filters=64, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = Conv2D(filters=64, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = BatchNormalization(momentum=0.15)(model)
model = MaxPool2D(pool_size=(2, 2))(model)
model = Conv2D(filters=64, kernel_size=(5, 5), padding='SAME', activation='relu')(model)
model = BatchNormalization(momentum=0.15)(model)
model = Dropout(rate=0.3)(model)

model = Conv2D(filters=128, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = Conv2D(filters=128, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = Conv2D(filters=128, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = Conv2D(filters=128, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = BatchNormalization(momentum=0.15)(model)
model = MaxPool2D(pool_size=(2, 2))(model)
model = Conv2D(filters=128, kernel_size=(5, 5), padding='SAME', activation='relu')(model)
model = BatchNormalization(momentum=0.15)(model)
model = Dropout(rate=0.3)(model)

model = Conv2D(filters=256, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = Conv2D(filters=256, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = Conv2D(filters=256, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = Conv2D(filters=256, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = BatchNormalization(momentum=0.15)(model)
model = MaxPool2D(pool_size=(2, 2))(model)
model = Conv2D(filters=256, kernel_size=(5, 5), padding='SAME', activation='relu')(model)
model = BatchNormalization(momentum=0.15)(model)
model = Dropout(rate=0.3)(model)

model = Flatten()(model)
model = Dense(1024, activation = "relu")(model)
model = Dropout(rate=0.3)(model)
dense = Dense(512, activation = "relu")(model)

head_root = Dense(168, activation = 'softmax')(dense)
head_vowel = Dense(11, activation = 'softmax')(dense)
head_consonant = Dense(7, activation = 'softmax')(dense)

model = Model(inputs=inputs, outputs=[head_root, head_vowel, head_consonant])

# %%
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 64, 64, 1)    0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 64, 64, 32)   320         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 64, 64, 32)   9248        conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 64, 64, 32)   9248        conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 64, 64, 32)   9248        conv2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 64, 64, 32)   128         conv2d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 32, 32, 32)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 32, 32, 32)   25632       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 32, 32, 32)   0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 32, 32, 64)   18496       dropout_1[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 32, 32, 64)   36928       conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 32, 32, 64)   36928       conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 32, 32, 64)   36928       conv2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 32, 32, 64)   256         conv2d_9[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 16, 16, 64)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 16, 16, 64)   102464      max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 16, 16, 64)   256         conv2d_10[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 16, 16, 64)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 16, 16, 128)  73856       dropout_2[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 16, 16, 128)  147584      conv2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 16, 16, 128)  147584      conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 16, 16, 128)  147584      conv2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 16, 16, 128)  512         conv2d_14[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 8, 8, 128)    0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 8, 8, 128)    409728      max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 8, 8, 128)    512         conv2d_15[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 8, 8, 128)    0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 8, 8, 256)    295168      dropout_3[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 8, 8, 256)    590080      conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 8, 8, 256)    590080      conv2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 8, 8, 256)    590080      conv2d_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 8, 8, 256)    1024        conv2d_19[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 4, 4, 256)    0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 4, 4, 256)    1638656     max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 4, 4, 256)    1024        conv2d_20[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 4, 4, 256)    0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 4096)         0           dropout_4[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1024)         4195328     flatten_1[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 1024)         0           dense_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 512)          524800      dropout_5[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 168)          86184       dense_2[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 11)           5643        dense_2[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 7)            3591        dense_2[0][0]
# ==================================================================================================
# Total params: 9,735,098
# Trainable params: 9,733,242
# Non-trainable params: 1,856
# __________________________________________________________________________________________________

# %% [markdown]
# Let's visualize the 3-tailed (3 output) CNN by plotting it.

# %%
from keras.utils import plot_model
plot_model(model, to_file='model.png')

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# Set a learning rate annealer. Learning rate will be half after 3 epochs if accuracy is not increased
learning_rate_reduction_root = ReduceLROnPlateau(monitor='dense_3_accuracy', 
                                            patience=3, 
                                            verbose=1,
                                            factor=0.5, 
                                            min_lr=0.00001)
learning_rate_reduction_vowel = ReduceLROnPlateau(monitor='dense_4_accuracy', 
                                            patience=3, 
                                            verbose=1,
                                            factor=0.5, 
                                            min_lr=0.00001)
learning_rate_reduction_consonant = ReduceLROnPlateau(monitor='dense_5_accuracy', 
                                            patience=3, 
                                            verbose=1,
                                            factor=0.5, 
                                            min_lr=0.00001)

# %%
batch_size = 256
epochs = 30

# %%
class MultiOutputDataGenerator(keras.preprocessing.image.ImageDataGenerator):

    def flow(self,
             x,
             y=None,
             batch_size=32,
             shuffle=True,
             sample_weight=None,
             seed=None,
             save_to_dir=None,
             save_prefix='',
             save_format='png',
             subset=None):

        targets = None
        target_lengths = {}
        ordered_outputs = []
        for output, target in y.items():
            if targets is None:
                targets = target
            else:
                targets = np.concatenate((targets, target), axis=1)
            target_lengths[output] = target.shape[1]
            ordered_outputs.append(output)


        for flowx, flowy in super().flow(x, targets, batch_size=batch_size,
                                         shuffle=shuffle):
            target_dict = {}
            i = 0
            for output in ordered_outputs:
                target_length = target_lengths[output]
                target_dict[output] = flowy[:, i: i + target_length]
                i += target_length

            yield flowx, target_dict

# %%
HEIGHT = 137
WIDTH = 236

# %% [markdown]
# ### Training loop

# %%
histories = []
for i in range(4):
    train_df = pd.merge(pd.read_parquet(f'/kaggle/input/bengaliai-cv19/train_image_data_{i}.parquet'), train_df_, on='image_id').drop(['image_id'], axis=1)
    
    # Visualize few samples of current training dataset
    fig, ax = plt.subplots(nrows=3, ncols=4, figsize=(16, 8))
    count=0
    for row in ax:
        for col in row:
            col.imshow(resize(train_df.drop(['grapheme_root', 'vowel_diacritic', 'consonant_diacritic'], axis=1).iloc[[count]], need_progress_bar=False).values.reshape(-1).reshape(IMG_SIZE, IMG_SIZE).astype(np.float64))
            count += 1
    plt.show()
    
    X_train = train_df.drop(['grapheme_root', 'vowel_diacritic', 'consonant_diacritic'], axis=1)
    X_train = resize(X_train)/255
    
    # CNN takes images in shape `(batch_size, h, w, channels)`, so reshape the images
    X_train = X_train.values.reshape(-1, IMG_SIZE, IMG_SIZE, N_CHANNELS)
    
    Y_train_root = pd.get_dummies(train_df['grapheme_root']).values
    Y_train_vowel = pd.get_dummies(train_df['vowel_diacritic']).values
    Y_train_consonant = pd.get_dummies(train_df['consonant_diacritic']).values

    print(f'Training images: {X_train.shape}')
    print(f'Training labels root: {Y_train_root.shape}')
    print(f'Training labels vowel: {Y_train_vowel.shape}')
    print(f'Training labels consonants: {Y_train_consonant.shape}')

    # Divide the data into training and validation set
    x_train, x_test, y_train_root, y_test_root, y_train_vowel, y_test_vowel, y_train_consonant, y_test_consonant = train_test_split(X_train, Y_train_root, Y_train_vowel, Y_train_consonant, test_size=0.08, random_state=666)
    del train_df
    del X_train
    del Y_train_root, Y_train_vowel, Y_train_consonant

    # Data augmentation for creating more training data
    datagen = MultiOutputDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        rotation_range=8,  # randomly rotate images in the range (degrees, 0 to 180)
        zoom_range = 0.15, # Randomly zoom image 
        width_shift_range=0.15,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=0.15,  # randomly shift images vertically (fraction of total height)
        horizontal_flip=False,  # randomly flip images
        vertical_flip=False)  # randomly flip images


    # This will just calculate parameters required to augment the given data. This won't perform any augmentations
    datagen.fit(x_train)

    # Fit the model
    history = model.fit_generator(datagen.flow(x_train, {'dense_3': y_train_root, 'dense_4': y_train_vowel, 'dense_5': y_train_consonant}, batch_size=batch_size),
                              epochs = epochs, validation_data = (x_test, [y_test_root, y_test_vowel, y_test_consonant]), 
                              steps_per_epoch=x_train.shape[0] // batch_size, 
                              callbacks=[learning_rate_reduction_root, learning_rate_reduction_vowel, learning_rate_reduction_consonant])

    histories.append(history)
    
    # Delete to reduce memory usage
    del x_train
    del x_test
    del y_train_root
    del y_test_root
    del y_train_vowel
    del y_test_vowel
    del y_train_consonant
    del y_test_consonant
    gc.collect()
# Out:
# HBox(children=(IntProgress(value=0, max=50210), HTML(value='')))
# Training images: (50210, 64, 64, 1)
# Training labels root: (50210, 168)
# Training labels vowel: (50210, 11)
# Training labels consonants: (50210, 7)
# Epoch 1/30
# 180/180 [==============================] - 44s 244ms/step - loss: 7.8287 - dense_3_loss: 4.7397 - dense_4_loss: 1.9212 - dense_5_loss: 1.1678 - dense_3_accuracy: 0.0293 - dense_4_accuracy: 0.3249 - dense_5_accuracy: 0.6260 - val_loss: 6.6263 - val_dense_3_loss: 4.4909 - val_dense_4_loss: 1.1702 - val_dense_5_loss: 0.9636 - val_dense_3_accuracy: 0.0411 - val_dense_4_accuracy: 0.5860 - val_dense_5_accuracy: 0.6604
# Epoch 2/30
# 180/180 [==============================] - 35s 197ms/step - loss: 6.5650 - dense_3_loss: 4.3221 - dense_4_loss: 1.2734 - dense_5_loss: 0.9695 - dense_3_accuracy: 0.0554 - dense_4_accuracy: 0.5498 - dense_5_accuracy: 0.6651 - val_loss: 5.7675 - val_dense_3_loss: 4.0837 - val_dense_4_loss: 0.9056 - val_dense_5_loss: 0.7853 - val_dense_3_accuracy: 0.0752 - val_dense_4_accuracy: 0.6878 - val_dense_5_accuracy: 0.7242
# Epoch 3/30
# 180/180 [==============================] - 35s 194ms/step - loss: 5.7940 - dense_3_loss: 3.9750 - dense_4_loss: 1.0132 - dense_5_loss: 0.8057 - dense_3_accuracy: 0.0813 - dense_4_accuracy: 0.6505 - dense_5_accuracy: 0.7193 - val_loss: 4.7122 - val_dense_3_loss: 3.5593 - val_dense_4_loss: 0.6003 - val_dense_5_loss: 0.5575 - val_dense_3_accuracy: 0.1299 - val_dense_4_accuracy: 0.8008 - val_dense_5_accuracy: 0.7984
# Epoch 4/30
# 180/180 [==============================] - 35s 196ms/step - loss: 4.9264 - dense_3_loss: 3.5110 - dense_4_loss: 0.8014 - dense_5_loss: 0.6140 - dense_3_accuracy: 0.1343 - dense_4_accuracy: 0.7329 - dense_5_accuracy: 0.7910 - val_loss: 3.6116 - val_dense_3_loss: 2.8129 - val_dense_4_loss: 0.4254 - val_dense_5_loss: 0.3771 - val_dense_3_accuracy: 0.2235 - val_dense_4_accuracy: 0.8628 - val_dense_5_accuracy: 0.8775
# Epoch 5/30
# 180/180 [==============================] - 35s 197ms/step - loss: 4.1015 - dense_3_loss: 2.9120 - dense_4_loss: 0.6898 - dense_5_loss: 0.4997 - dense_3_accuracy: 0.2306 - dense_4_accuracy: 0.7755 - dense_5_accuracy: 0.8324 - val_loss: 2.9558 - val_dense_3_loss: 2.2639 - val_dense_4_loss: 0.3810 - val_dense_5_loss: 0.3127 - val_dense_3_accuracy: 0.3570 - val_dense_4_accuracy: 0.8740 - val_dense_5_accuracy: 0.8932
# Epoch 6/30
# 180/180 [==============================] - 35s 192ms/step - loss: 3.3486 - dense_3_loss: 2.3286 - dense_4_loss: 0.5925 - dense_5_loss: 0.4275 - dense_3_accuracy: 0.3520 - dense_4_accuracy: 0.8094 - dense_5_accuracy: 0.8587 - val_loss: 2.4160 - val_dense_3_loss: 1.7318 - val_dense_4_loss: 0.3843 - val_dense_5_loss: 0.3046 - val_dense_3_accuracy: 0.4909 - val_dense_4_accuracy: 0.8773 - val_dense_5_accuracy: 0.8920
# Epoch 7/30
# 180/180 [==============================] - 35s 197ms/step - loss: 2.7458 - dense_3_loss: 1.8472 - dense_4_loss: 0.5263 - dense_5_loss: 0.3723 - dense_3_accuracy: 0.4759 - dense_4_accuracy: 0.8311 - dense_5_accuracy: 0.8776 - val_loss: 1.7908 - val_dense_3_loss: 1.2405 - val_dense_4_loss: 0.3071 - val_dense_5_loss: 0.2452 - val_dense_3_accuracy: 0.6308 - val_dense_4_accuracy: 0.9042 - val_dense_5_accuracy: 0.9181
# Epoch 8/30
# 180/180 [==============================] - 35s 194ms/step - loss: 2.2739 - dense_3_loss: 1.4807 - dense_4_loss: 0.4641 - dense_5_loss: 0.3291 - dense_3_accuracy: 0.5744 - dense_4_accuracy: 0.8555 - dense_5_accuracy: 0.8930 - val_loss: 1.3914 - val_dense_3_loss: 0.9730 - val_dense_4_loss: 0.2371 - val_dense_5_loss: 0.1834 - val_dense_3_accuracy: 0.7179 - val_dense_4_accuracy: 0.9263 - val_dense_5_accuracy: 0.9380
# Epoch 9/30
# 180/180 [==============================] - 36s 198ms/step - loss: 1.9730 - dense_3_loss: 1.2594 - dense_4_loss: 0.4209 - dense_5_loss: 0.2927 - dense_3_accuracy: 0.6393 - dense_4_accuracy: 0.8674 - dense_5_accuracy: 0.9050 - val_loss: 1.1297 - val_dense_3_loss: 0.7715 - val_dense_4_loss: 0.2092 - val_dense_5_loss: 0.1539 - val_dense_3_accuracy: 0.7755 - val_dense_4_accuracy: 0.9358 - val_dense_5_accuracy: 0.9495
# Epoch 10/30
# 180/180 [==============================] - 35s 196ms/step - loss: 1.7377 - dense_3_loss: 1.0939 - dense_4_loss: 0.3767 - dense_5_loss: 0.2672 - dense_3_accuracy: 0.6856 - dense_4_accuracy: 0.8834 - dense_5_accuracy: 0.9144 - val_loss: 1.0971 - val_dense_3_loss: 0.7134 - val_dense_4_loss: 0.2151 - val_dense_5_loss: 0.1694 - val_dense_3_accuracy: 0.7959 - val_dense_4_accuracy: 0.9360 - val_dense_5_accuracy: 0.9442
# Epoch 11/30
# 180/180 [==============================] - 35s 194ms/step - loss: 1.5645 - dense_3_loss: 0.9633 - dense_4_loss: 0.3512 - dense_5_loss: 0.2500 - dense_3_accuracy: 0.7231 - dense_4_accuracy: 0.8937 - dense_5_accuracy: 0.9210 - val_loss: 1.0056 - val_dense_3_loss: 0.6615 - val_dense_4_loss: 0.2017 - val_dense_5_loss: 0.1473 - val_dense_3_accuracy: 0.8116 - val_dense_4_accuracy: 0.9437 - val_dense_5_accuracy: 0.9547
# Epoch 12/30
# 180/180 [==============================] - 36s 198ms/step - loss: 1.4634 - dense_3_loss: 0.8888 - dense_4_loss: 0.3418 - dense_5_loss: 0.2328 - dense_3_accuracy: 0.7447 - dense_4_accuracy: 0.8974 - dense_5_accuracy: 0.9264 - val_loss: 0.8507 - val_dense_3_loss: 0.5797 - val_dense_4_loss: 0.1531 - val_dense_5_loss: 0.1177 - val_dense_3_accuracy: 0.8295 - val_dense_4_accuracy: 0.9552 - val_dense_5_accuracy: 0.9639
# Epoch 13/30
# 180/180 [==============================] - 35s 194ms/step - loss: 1.3083 - dense_3_loss: 0.7905 - dense_4_loss: 0.3072 - dense_5_loss: 0.2106 - dense_3_accuracy: 0.7711 - dense_4_accuracy: 0.9076 - dense_5_accuracy: 0.9328 - val_loss: 0.8262 - val_dense_3_loss: 0.5442 - val_dense_4_loss: 0.1532 - val_dense_5_loss: 0.1289 - val_dense_3_accuracy: 0.8402 - val_dense_4_accuracy: 0.9547 - val_dense_5_accuracy: 0.9569
# Epoch 14/30
# 180/180 [==============================] - 36s 198ms/step - loss: 1.2517 - dense_3_loss: 0.7495 - dense_4_loss: 0.2956 - dense_5_loss: 0.2067 - dense_3_accuracy: 0.7842 - dense_4_accuracy: 0.9111 - dense_5_accuracy: 0.9346 - val_loss: 0.7715 - val_dense_3_loss: 0.5120 - val_dense_4_loss: 0.1453 - val_dense_5_loss: 0.1145 - val_dense_3_accuracy: 0.8561 - val_dense_4_accuracy: 0.9604 - val_dense_5_accuracy: 0.9676
# Epoch 15/30
# 180/180 [==============================] - 35s 196ms/step - loss: 1.1650 - dense_3_loss: 0.6926 - dense_4_loss: 0.2773 - dense_5_loss: 0.1951 - dense_3_accuracy: 0.8032 - dense_4_accuracy: 0.9172 - dense_5_accuracy: 0.9397 - val_loss: 0.7068 - val_dense_3_loss: 0.4734 - val_dense_4_loss: 0.1339 - val_dense_5_loss: 0.0983 - val_dense_3_accuracy: 0.8668 - val_dense_4_accuracy: 0.9619 - val_dense_5_accuracy: 0.9711
# Epoch 16/30
# 180/180 [==============================] - 35s 194ms/step - loss: 1.1081 - dense_3_loss: 0.6475 - dense_4_loss: 0.2718 - dense_5_loss: 0.1889 - dense_3_accuracy: 0.8139 - dense_4_accuracy: 0.9191 - dense_5_accuracy: 0.9405 - val_loss: 0.7295 - val_dense_3_loss: 0.4729 - val_dense_4_loss: 0.1437 - val_dense_5_loss: 0.1136 - val_dense_3_accuracy: 0.8663 - val_dense_4_accuracy: 0.9627 - val_dense_5_accuracy: 0.9676
# Epoch 17/30
# 180/180 [==============================] - 35s 195ms/step - loss: 1.0460 - dense_3_loss: 0.6095 - dense_4_loss: 0.2562 - dense_5_loss: 0.1803 - dense_3_accuracy: 0.8225 - dense_4_accuracy: 0.9245 - dense_5_accuracy: 0.9430 - val_loss: 0.6923 - val_dense_3_loss: 0.4558 - val_dense_4_loss: 0.1454 - val_dense_5_loss: 0.0944 - val_dense_3_accuracy: 0.8778 - val_dense_4_accuracy: 0.9587 - val_dense_5_accuracy: 0.9709
# Epoch 18/30
# 180/180 [==============================] - 35s 192ms/step - loss: 1.0089 - dense_3_loss: 0.5858 - dense_4_loss: 0.2502 - dense_5_loss: 0.1729 - dense_3_accuracy: 0.8314 - dense_4_accuracy: 0.9257 - dense_5_accuracy: 0.9466 - val_loss: 0.6901 - val_dense_3_loss: 0.4375 - val_dense_4_loss: 0.1544 - val_dense_5_loss: 0.1021 - val_dense_3_accuracy: 0.8850 - val_dense_4_accuracy: 0.9594 - val_dense_5_accuracy: 0.9689
# Epoch 19/30
# 180/180 [==============================] - 35s 196ms/step - loss: 0.9648 - dense_3_loss: 0.5529 - dense_4_loss: 0.2443 - dense_5_loss: 0.1676 - dense_3_accuracy: 0.8407 - dense_4_accuracy: 0.9267 - dense_5_accuracy: 0.9479 - val_loss: 0.6666 - val_dense_3_loss: 0.4134 - val_dense_4_loss: 0.1489 - val_dense_5_loss: 0.1058 - val_dense_3_accuracy: 0.8897 - val_dense_4_accuracy: 0.9584 - val_dense_5_accuracy: 0.9709
# Epoch 20/30
# 180/180 [==============================] - 35s 192ms/step - loss: 0.9410 - dense_3_loss: 0.5390 - dense_4_loss: 0.2355 - dense_5_loss: 0.1665 - dense_3_accuracy: 0.8412 - dense_4_accuracy: 0.9291 - dense_5_accuracy: 0.9483 - val_loss: 0.6626 - val_dense_3_loss: 0.4081 - val_dense_4_loss: 0.1490 - val_dense_5_loss: 0.1055 - val_dense_3_accuracy: 0.8925 - val_dense_4_accuracy: 0.9574 - val_dense_5_accuracy: 0.9706
# Epoch 21/30
# 180/180 [==============================] - 35s 197ms/step - loss: 0.8968 - dense_3_loss: 0.5084 - dense_4_loss: 0.2281 - dense_5_loss: 0.1603 - dense_3_accuracy: 0.8542 - dense_4_accuracy: 0.9336 - dense_5_accuracy: 0.9504 - val_loss: 0.6031 - val_dense_3_loss: 0.3937 - val_dense_4_loss: 0.1187 - val_dense_5_loss: 0.0907 - val_dense_3_accuracy: 0.8905 - val_dense_4_accuracy: 0.9681 - val_dense_5_accuracy: 0.9729
# Epoch 22/30
# 180/180 [==============================] - 35s 195ms/step - loss: 0.8614 - dense_3_loss: 0.4869 - dense_4_loss: 0.2269 - dense_5_loss: 0.1476 - dense_3_accuracy: 0.8588 - dense_4_accuracy: 0.9335 - dense_5_accuracy: 0.9537 - val_loss: 0.6688 - val_dense_3_loss: 0.4073 - val_dense_4_loss: 0.1651 - val_dense_5_loss: 0.0996 - val_dense_3_accuracy: 0.8885 - val_dense_4_accuracy: 0.9584 - val_dense_5_accuracy: 0.9721
# Epoch 23/30
# 180/180 [==============================] - 35s 193ms/step - loss: 0.8472 - dense_3_loss: 0.4817 - dense_4_loss: 0.2156 - dense_5_loss: 0.1499 - dense_3_accuracy: 0.8592 - dense_4_accuracy: 0.9348 - dense_5_accuracy: 0.9544 - val_loss: 0.6240 - val_dense_3_loss: 0.3969 - val_dense_4_loss: 0.1313 - val_dense_5_loss: 0.0931 - val_dense_3_accuracy: 0.8949 - val_dense_4_accuracy: 0.9592 - val_dense_5_accuracy: 0.9726
# Epoch 24/30
# 180/180 [==============================] - 35s 197ms/step - loss: 0.8261 - dense_3_loss: 0.4624 - dense_4_loss: 0.2180 - dense_5_loss: 0.1458 - dense_3_accuracy: 0.8647 - dense_4_accuracy: 0.9365 - dense_5_accuracy: 0.9548 - val_loss: 0.5960 - val_dense_3_loss: 0.3877 - val_dense_4_loss: 0.1012 - val_dense_5_loss: 0.1050 - val_dense_3_accuracy: 0.9009 - val_dense_4_accuracy: 0.9719 - val_dense_5_accuracy: 0.9699
# Epoch 25/30
# 180/180 [==============================] - 35s 192ms/step - loss: 0.7799 - dense_3_loss: 0.4402 - dense_4_loss: 0.2021 - dense_5_loss: 0.1376 - dense_3_accuracy: 0.8720 - dense_4_accuracy: 0.9416 - dense_5_accuracy: 0.9565 - val_loss: 0.6000 - val_dense_3_loss: 0.3710 - val_dense_4_loss: 0.1343 - val_dense_5_loss: 0.0966 - val_dense_3_accuracy: 0.9012 - val_dense_4_accuracy: 0.9644 - val_dense_5_accuracy: 0.9729
# Epoch 26/30
# 180/180 [==============================] - 35s 196ms/step - loss: 0.7773 - dense_3_loss: 0.4319 - dense_4_loss: 0.2054 - dense_5_loss: 0.1400 - dense_3_accuracy: 0.8735 - dense_4_accuracy: 0.9398 - dense_5_accuracy: 0.9562 - val_loss: 0.5777 - val_dense_3_loss: 0.3757 - val_dense_4_loss: 0.1084 - val_dense_5_loss: 0.0945 - val_dense_3_accuracy: 0.8974 - val_dense_4_accuracy: 0.9689 - val_dense_5_accuracy: 0.9721
# Epoch 27/30
# 180/180 [==============================] - 35s 194ms/step - loss: 0.7423 - dense_3_loss: 0.4148 - dense_4_loss: 0.1955 - dense_5_loss: 0.1321 - dense_3_accuracy: 0.8820 - dense_4_accuracy: 0.9412 - dense_5_accuracy: 0.9592 - val_loss: 0.5816 - val_dense_3_loss: 0.3744 - val_dense_4_loss: 0.1123 - val_dense_5_loss: 0.0953 - val_dense_3_accuracy: 0.8964 - val_dense_4_accuracy: 0.9699 - val_dense_5_accuracy: 0.9724
# Epoch 28/30
# 180/180 [==============================] - 35s 195ms/step - loss: 0.7351 - dense_3_loss: 0.4104 - dense_4_loss: 0.1912 - dense_5_loss: 0.1335 - dense_3_accuracy: 0.8779 - dense_4_accuracy: 0.9430 - dense_5_accuracy: 0.9583 - val_loss: 0.5843 - val_dense_3_loss: 0.3843 - val_dense_4_loss: 0.1048 - val_dense_5_loss: 0.0939 - val_dense_3_accuracy: 0.8994 - val_dense_4_accuracy: 0.9709 - val_dense_5_accuracy: 0.9736
# Epoch 29/30
# 180/180 [==============================] - 36s 197ms/step - loss: 0.7131 - dense_3_loss: 0.3874 - dense_4_loss: 0.1932 - dense_5_loss: 0.1325 - dense_3_accuracy: 0.8861 - dense_4_accuracy: 0.9434 - dense_5_accuracy: 0.9592 - val_loss: 0.5172 - val_dense_3_loss: 0.3387 - val_dense_4_loss: 0.0935 - val_dense_5_loss: 0.0863 - val_dense_3_accuracy: 0.9076 - val_dense_4_accuracy: 0.9744 - val_dense_5_accuracy: 0.9761
# Epoch 30/30
# 180/180 [==============================] - 35s 194ms/step - loss: 0.7037 - dense_3_loss: 0.3800 - dense_4_loss: 0.1943 - dense_5_loss: 0.1293 - dense_3_accuracy: 0.8885 - dense_4_accuracy: 0.9429 - dense_5_accuracy: 0.9604 - val_loss: 0.5523 - val_dense_3_loss: 0.3655 - val_dense_4_loss: 0.0976 - val_dense_5_loss: 0.0875 - val_dense_3_accuracy: 0.9059 - val_dense_4_accuracy: 0.9716 - val_dense_5_accuracy: 0.9746
# HBox(children=(IntProgress(value=0, max=50210), HTML(value='')))
# Training images: (50210, 64, 64, 1)
# Training labels root: (50210, 168)
# Training labels vowel: (50210, 11)
# Training labels consonants: (50210, 7)
# Epoch 1/30
# 180/180 [==============================] - 37s 203ms/step - loss: 0.9833 - dense_3_loss: 0.5709 - dense_4_loss: 0.2407 - dense_5_loss: 0.1718 - dense_3_accuracy: 0.8451 - dense_4_accuracy: 0.9316 - dense_5_accuracy: 0.9486 - val_loss: 0.5139 - val_dense_3_loss: 0.3108 - val_dense_4_loss: 0.1156 - val_dense_5_loss: 0.0871 - val_dense_3_accuracy: 0.9151 - val_dense_4_accuracy: 0.9709 - val_dense_5_accuracy: 0.9734
# Epoch 2/30
# 180/180 [==============================] - 36s 198ms/step - loss: 0.8807 - dense_3_loss: 0.5031 - dense_4_loss: 0.2229 - dense_5_loss: 0.1547 - dense_3_accuracy: 0.8603 - dense_4_accuracy: 0.9364 - dense_5_accuracy: 0.9529 - val_loss: 0.4584 - val_dense_3_loss: 0.2856 - val_dense_4_loss: 0.0917 - val_dense_5_loss: 0.0804 - val_dense_3_accuracy: 0.9218 - val_dense_4_accuracy: 0.9756 - val_dense_5_accuracy: 0.9773
# Epoch 3/30
# 180/180 [==============================] - 35s 195ms/step - loss: 0.8166 - dense_3_loss: 0.4622 - dense_4_loss: 0.2092 - dense_5_loss: 0.1452 - dense_3_accuracy: 0.8704 - dense_4_accuracy: 0.9396 - dense_5_accuracy: 0.9560 - val_loss: 0.5050 - val_dense_3_loss: 0.3063 - val_dense_4_loss: 0.1062 - val_dense_5_loss: 0.0918 - val_dense_3_accuracy: 0.9156 - val_dense_4_accuracy: 0.9716 - val_dense_5_accuracy: 0.9731
# Epoch 4/30
# 180/180 [==============================] - 36s 198ms/step - loss: 0.7791 - dense_3_loss: 0.4320 - dense_4_loss: 0.2021 - dense_5_loss: 0.1451 - dense_3_accuracy: 0.8780 - dense_4_accuracy: 0.9414 - dense_5_accuracy: 0.9564 - val_loss: 0.4668 - val_dense_3_loss: 0.2940 - val_dense_4_loss: 0.0972 - val_dense_5_loss: 0.0745 - val_dense_3_accuracy: 0.9193 - val_dense_4_accuracy: 0.9734 - val_dense_5_accuracy: 0.9783
# Epoch 5/30
# 180/180 [==============================] - 36s 198ms/step - loss: 0.7597 - dense_3_loss: 0.4173 - dense_4_loss: 0.2034 - dense_5_loss: 0.1390 - dense_3_accuracy: 0.8794 - dense_4_accuracy: 0.9417 - dense_5_accuracy: 0.9575 - val_loss: 0.4847 - val_dense_3_loss: 0.2951 - val_dense_4_loss: 0.1060 - val_dense_5_loss: 0.0813 - val_dense_3_accuracy: 0.9171 - val_dense_4_accuracy: 0.9711 - val_dense_5_accuracy: 0.9778
# Epoch 6/30
# 180/180 [==============================] - 35s 197ms/step - loss: 0.7374 - dense_3_loss: 0.4076 - dense_4_loss: 0.1953 - dense_5_loss: 0.1344 - dense_3_accuracy: 0.8843 - dense_4_accuracy: 0.9434 - dense_5_accuracy: 0.9590 - val_loss: 0.4486 - val_dense_3_loss: 0.2794 - val_dense_4_loss: 0.0869 - val_dense_5_loss: 0.0815 - val_dense_3_accuracy: 0.9253 - val_dense_4_accuracy: 0.9759 - val_dense_5_accuracy: 0.9751
# Epoch 7/30
# 180/180 [==============================] - 36s 198ms/step - loss: 0.7019 - dense_3_loss: 0.3831 - dense_4_loss: 0.1886 - dense_5_loss: 0.1302 - dense_3_accuracy: 0.8888 - dense_4_accuracy: 0.9454 - dense_5_accuracy: 0.9614 - val_loss: 0.4630 - val_dense_3_loss: 0.2857 - val_dense_4_loss: 0.0952 - val_dense_5_loss: 0.0800 - val_dense_3_accuracy: 0.9156 - val_dense_4_accuracy: 0.9744 - val_dense_5_accuracy: 0.9766
# Epoch 8/30
# 180/180 [==============================] - 35s 196ms/step - loss: 0.6776 - dense_3_loss: 0.3659 - dense_4_loss: 0.1863 - dense_5_loss: 0.1253 - dense_3_accuracy: 0.8927 - dense_4_accuracy: 0.9454 - dense_5_accuracy: 0.9615 - val_loss: 0.4469 - val_dense_3_loss: 0.2739 - val_dense_4_loss: 0.0935 - val_dense_5_loss: 0.0765 - val_dense_3_accuracy: 0.9238 - val_dense_4_accuracy: 0.9791 - val_dense_5_accuracy: 0.9801
# Epoch 9/30
# 180/180 [==============================] - 36s 201ms/step - loss: 0.6513 - dense_3_loss: 0.3516 - dense_4_loss: 0.1804 - dense_5_loss: 0.1194 - dense_3_accuracy: 0.8980 - dense_4_accuracy: 0.9478 - dense_5_accuracy: 0.9631 - val_loss: 0.4402 - val_dense_3_loss: 0.2669 - val_dense_4_loss: 0.0943 - val_dense_5_loss: 0.0781 - val_dense_3_accuracy: 0.9258 - val_dense_4_accuracy: 0.9778 - val_dense_5_accuracy: 0.9793
# Epoch 10/30
# 180/180 [==============================] - 35s 197ms/step - loss: 0.6363 - dense_3_loss: 0.3423 - dense_4_loss: 0.1694 - dense_5_loss: 0.1246 - dense_3_accuracy: 0.9008 - dense_4_accuracy: 0.9511 - dense_5_accuracy: 0.9625 - val_loss: 0.4928 - val_dense_3_loss: 0.2768 - val_dense_4_loss: 0.1214 - val_dense_5_loss: 0.0928 - val_dense_3_accuracy: 0.9253 - val_dense_4_accuracy: 0.9694 - val_dense_5_accuracy: 0.9746
# Epoch 11/30
# 180/180 [==============================] - 36s 199ms/step - loss: 0.6288 - dense_3_loss: 0.3356 - dense_4_loss: 0.1768 - dense_5_loss: 0.1164 - dense_3_accuracy: 0.9016 - dense_4_accuracy: 0.9487 - dense_5_accuracy: 0.9649 - val_loss: 0.4363 - val_dense_3_loss: 0.2675 - val_dense_4_loss: 0.0864 - val_dense_5_loss: 0.0812 - val_dense_3_accuracy: 0.9313 - val_dense_4_accuracy: 0.9766 - val_dense_5_accuracy: 0.9746
# Epoch 12/30
# 180/180 [==============================] - 36s 199ms/step - loss: 0.6125 - dense_3_loss: 0.3286 - dense_4_loss: 0.1669 - dense_5_loss: 0.1170 - dense_3_accuracy: 0.9036 - dense_4_accuracy: 0.9528 - dense_5_accuracy: 0.9646 - val_loss: 0.4487 - val_dense_3_loss: 0.2695 - val_dense_4_loss: 0.0953 - val_dense_5_loss: 0.0828 - val_dense_3_accuracy: 0.9293 - val_dense_4_accuracy: 0.9776 - val_dense_5_accuracy: 0.9783
# Epoch 13/30
# 180/180 [==============================] - 35s 194ms/step - loss: 0.5906 - dense_3_loss: 0.3153 - dense_4_loss: 0.1638 - dense_5_loss: 0.1116 - dense_3_accuracy: 0.9063 - dense_4_accuracy: 0.9524 - dense_5_accuracy: 0.9657 - val_loss: 0.4618 - val_dense_3_loss: 0.2744 - val_dense_4_loss: 0.0983 - val_dense_5_loss: 0.0894 - val_dense_3_accuracy: 0.9278 - val_dense_4_accuracy: 0.9746 - val_dense_5_accuracy: 0.9761
# Epoch 14/30
# 167/180 [==========================>...] - ETA: 2s - loss: 0.5771 - dense_3_loss: 0.3034 - dense_4_loss: 0.1644 - dense_5_loss: 0.1093 - dense_3_accuracy: 0.9100 - dense_4_accuracy: 0.9525 - dense_5_accuracy: 0.9676
# HBox(children=(IntProgress(value=0, max=50210), HTML(value='')))
# 180/180 [==============================] - 36s 198ms/step - loss: 0.4169 - dense_3_loss: 0.2200 - dense_4_loss: 0.1191 - dense_5_loss: 0.0779 - dense_3_accuracy: 0.9349 - dense_4_accuracy: 0.9658 - dense_5_accuracy: 0.9763 - val_loss: 0.3317 - val_dense_3_loss: 0.1890 - val_dense_4_loss: 0.0801 - val_dense_5_loss: 0.0655 - val_dense_3_accuracy: 0.9497 - val_dense_4_accuracy: 0.9798 - val_dense_5_accuracy: 0.9806
# Epoch 10/30
# 180/180 [==============================] - 35s 193ms/step - loss: 0.4132 - dense_3_loss: 0.2159 - dense_4_loss: 0.1177 - dense_5_loss: 0.0796 - dense_3_accuracy: 0.9348 - dense_4_accuracy: 0.9656 - dense_5_accuracy: 0.9757 - val_loss: 0.3229 - val_dense_3_loss: 0.1842 - val_dense_4_loss: 0.0766 - val_dense_5_loss: 0.0624 - val_dense_3_accuracy: 0.9492 - val_dense_4_accuracy: 0.9828 - val_dense_5_accuracy: 0.9831
# Epoch 11/30
# 180/180 [==============================] - 36s 198ms/step - loss: 0.3932 - dense_3_loss: 0.2053 - dense_4_loss: 0.1092 - dense_5_loss: 0.0786 - dense_3_accuracy: 0.9375 - dense_4_accuracy: 0.9675 - dense_5_accuracy: 0.9765 - val_loss: 0.3408 - val_dense_3_loss: 0.1912 - val_dense_4_loss: 0.0875 - val_dense_5_loss: 0.0657 - val_dense_3_accuracy: 0.9502 - val_dense_4_accuracy: 0.9796 - val_dense_5_accuracy: 0.9806
# Epoch 12/30
# 180/180 [==============================] - 35s 196ms/step - loss: 0.2930 - dense_3_loss: 0.1426 - dense_4_loss: 0.0916 - dense_5_loss: 0.0587 - dense_3_accuracy: 0.9555 - dense_4_accuracy: 0.9727 - dense_5_accuracy: 0.9822 - val_loss: 0.3434 - val_dense_3_loss: 0.2079 - val_dense_4_loss: 0.0718 - val_dense_5_loss: 0.0662 - val_dense_3_accuracy: 0.9490 - val_dense_4_accuracy: 0.9806 - val_dense_5_accuracy: 0.9811
# Epoch 25/30
# 180/180 [==============================] - 35s 196ms/step - loss: 0.2860 - dense_3_loss: 0.1400 - dense_4_loss: 0.0885 - dense_5_loss: 0.0575 - dense_3_accuracy: 0.9571 - dense_4_accuracy: 0.9745 - dense_5_accuracy: 0.9825 - val_loss: 0.3431 - val_dense_3_loss: 0.1998 - val_dense_4_loss: 0.0759 - val_dense_5_loss: 0.0686 - val_dense_3_accuracy: 0.9472 - val_dense_4_accuracy: 0.9798 - val_dense_5_accuracy: 0.9806
# Epoch 26/30
# 180/180 [==============================] - 36s 198ms/step - loss: 0.4932 - dense_3_loss: 0.2787 - dense_4_loss: 0.1245 - dense_5_loss: 0.0900 - dense_3_accuracy: 0.9232 - dense_4_accuracy: 0.9647 - dense_5_accuracy: 0.9735 - val_loss: 0.2939 - val_dense_3_loss: 0.1862 - val_dense_4_loss: 0.0630 - val_dense_5_loss: 0.0443 - val_dense_3_accuracy: 0.9507 - val_dense_4_accuracy: 0.9846 - val_dense_5_accuracy: 0.9883
# Epoch 4/30
# 180/180 [==============================] - 35s 196ms/step - loss: 0.4651 - dense_3_loss: 0.2613 - dense_4_loss: 0.1191 - dense_5_loss: 0.0846 - dense_3_accuracy: 0.9270 - dense_4_accuracy: 0.9655 - dense_5_accuracy: 0.9750 - val_loss: 0.2882 - val_dense_3_loss: 0.1794 - val_dense_4_loss: 0.0633 - val_dense_5_loss: 0.0444 - val_dense_3_accuracy: 0.9522 - val_dense_4_accuracy: 0.9848 - val_dense_5_accuracy: 0.9885
# Epoch 5/30
# 180/180 [==============================] - 35s 194ms/step - loss: 0.3886 - dense_3_loss: 0.2112 - dense_4_loss: 0.1029 - dense_5_loss: 0.0745 - dense_3_accuracy: 0.9381 - dense_4_accuracy: 0.9698 - dense_5_accuracy: 0.9776 - val_loss: 0.2856 - val_dense_3_loss: 0.1787 - val_dense_4_loss: 0.0620 - val_dense_5_loss: 0.0438 - val_dense_3_accuracy: 0.9534 - val_dense_4_accuracy: 0.9836 - val_dense_5_accuracy: 0.9885
# Epoch 18/30
# 180/180 [==============================] - 35s 197ms/step - loss: 0.3823 - dense_3_loss: 0.2081 - dense_4_loss: 0.1032 - dense_5_loss: 0.0710 - dense_3_accuracy: 0.9389 - dense_4_accuracy: 0.9704 - dense_5_accuracy: 0.9786 - val_loss: 0.2837 - val_dense_3_loss: 0.1765 - val_dense_4_loss: 0.0624 - val_dense_5_loss: 0.0439 - val_dense_3_accuracy: 0.9525 - val_dense_4_accuracy: 0.9826 - val_dense_5_accuracy: 0.9885
# Epoch 19/30
# 180/180 [==============================] - 35s 193ms/step - loss: 0.3912 - dense_3_loss: 0.2117 - dense_4_loss: 0.1054 - dense_5_loss: 0.0741 - dense_3_accuracy: 0.9381 - dense_4_accuracy: 0.9688 - dense_5_accuracy: 0.9770 - val_loss: 0.2796 - val_dense_3_loss: 0.1756 - val_dense_4_loss: 0.0595 - val_dense_5_loss: 0.0437 - val_dense_3_accuracy: 0.9517 - val_dense_4_accuracy: 0.9826 - val_dense_5_accuracy: 0.9893
# Epoch 20/30
#   5/180 [..............................] - ETA: 32s - loss: 0.3552 - dense_3_loss: 0.1913 - dense_4_loss: 0.0862 - dense_5_loss: 0.0777 - dense_3_accuracy: 0.9414 - dense_4_accuracy: 0.9727 - dense_5_accuracy: 0.9758

# %%
# %matplotlib inline
def plot_loss(his, epoch, title):
    plt.style.use('ggplot')
    plt.figure()
    plt.plot(np.arange(0, epoch), his.history['loss'], label='train_loss')
    plt.plot(np.arange(0, epoch), his.history['dense_3_loss'], label='train_root_loss')
    plt.plot(np.arange(0, epoch), his.history['dense_4_loss'], label='train_vowel_loss')
    plt.plot(np.arange(0, epoch), his.history['dense_5_loss'], label='train_consonant_loss')
    
    plt.plot(np.arange(0, epoch), his.history['val_dense_3_loss'], label='val_train_root_loss')
    plt.plot(np.arange(0, epoch), his.history['val_dense_4_loss'], label='val_train_vowel_loss')
    plt.plot(np.arange(0, epoch), his.history['val_dense_5_loss'], label='val_train_consonant_loss')
    
    plt.title(title)
    plt.xlabel('Epoch #')
    plt.ylabel('Loss')
    plt.legend(loc='upper right')
    plt.show()

def plot_acc(his, epoch, title):
    plt.style.use('ggplot')
    plt.figure()
    plt.plot(np.arange(0, epoch), his.history['dense_3_accuracy'], label='train_root_acc')
    plt.plot(np.arange(0, epoch), his.history['dense_4_accuracy'], label='train_vowel_accuracy')
    plt.plot(np.arange(0, epoch), his.history['dense_5_accuracy'], label='train_consonant_accuracy')
    
    plt.plot(np.arange(0, epoch), his.history['val_dense_3_accuracy'], label='val_root_acc')
    plt.plot(np.arange(0, epoch), his.history['val_dense_4_accuracy'], label='val_vowel_accuracy')
    plt.plot(np.arange(0, epoch), his.history['val_dense_5_accuracy'], label='val_consonant_accuracy')
    plt.title(title)
    plt.xlabel('Epoch #')
    plt.ylabel('Accuracy')
    plt.legend(loc='upper right')
    plt.show()

# %%
for dataset in range(4):
    plot_loss(histories[dataset], epochs, f'Training Dataset: {dataset}')
    plot_acc(histories[dataset], epochs, f'Training Dataset: {dataset}')

# %%
del histories
gc.collect()
# Out:
# 27023

# %%
preds_dict = {
    'grapheme_root': [],
    'vowel_diacritic': [],
    'consonant_diacritic': []
}

# %%
components = ['consonant_diacritic', 'grapheme_root', 'vowel_diacritic']
target=[] # model predictions placeholder
row_id=[] # row_id place holder
for i in range(4):
    df_test_img = pd.read_parquet('/kaggle/input/bengaliai-cv19/test_image_data_{}.parquet'.format(i)) 
    df_test_img.set_index('image_id', inplace=True)

    X_test = resize(df_test_img, need_progress_bar=False)/255
    X_test = X_test.values.reshape(-1, IMG_SIZE, IMG_SIZE, N_CHANNELS)
    
    preds = model.predict(X_test)

    for i, p in enumerate(preds_dict):
        preds_dict[p] = np.argmax(preds[i], axis=1)

    for k,id in enumerate(df_test_img.index.values):  
        for i,comp in enumerate(components):
            id_sample=id+'_'+comp
            row_id.append(id_sample)
            target.append(preds_dict[comp][k])
    del df_test_img
    del X_test
    gc.collect()

df_sample = pd.DataFrame(
    {
        'row_id': row_id,
        'target':target
    },
    columns = ['row_id','target'] 
)
df_sample.to_csv('submission.csv',index=False)
df_sample.head()
# Out:
#                        row_id  target
# 0  Test_0_consonant_diacritic       0
# 1        Test_0_grapheme_root       3
# 2      Test_0_vowel_diacritic       0
# 3  Test_1_consonant_diacritic       0
# 4        Test_1_grapheme_root      93

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
